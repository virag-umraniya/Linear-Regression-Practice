# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Collect or Load Dataset

# %%
df = pd.read_csv("EcommerceCustomers.csv")

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %% [markdown]
# ## 2. Domain Analysis - Ecommerce Customers Dataset
#
# This dataset contains information about **Ecommerce platform users**, capturing their behavior on the platform and key metrics tied to spending patterns.
#
# ### i. Dataset Description
# The dataset includes the following features:
#
# - **Email**: Customer email address (identifier).
# - **Address**: Full physical address of the customer.
# - **Avatar**: Categorical variable representing user's profile avatar color.
# - **Avg. Session Length**: Average session length on the website (in minutes).
# - **Time on App**: Average time spent on the mobile app (in minutes).
# - **Time on Website**: Average time spent on the website (in minutes).
# - **Length of Membership**: Number of years the customer has been a member.
# - **Yearly Amount Spent**: Target variable — total amount of money (in USD) the customer spends in a year.
#
# ### ii. Objective
# The primary goal is to analyze **user behavior** to determine:
# - What drives higher spending?
# - How usage patterns differ between app vs. website.
# - Which features correlate strongly with the **Yearly Amount Spent**.
#
# ### iii. Data Types
# - **Categorical**: Avatar
# - **Textual**: Email, Address
# - **Numerical**: All other columns
#
# ### iv. Use Cases
# - Customer segmentation based on spending patterns.
# - Personalized marketing strategies.
# - Feature importance for predictive modeling.

# %% [markdown]
# ## 3. Basic Checks

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.describe(include = 'object')
# Out:
#                             Email  \
# count                         500
# unique                        500
# top     mstephenson@fernandez.com
# freq                            1
#
#                                              Address     Avatar
# count                                            500        500
# unique                                           500        138
# top     835 Frank Tunnel\nWrightmouth, MI 82180-9605  SlateBlue
# freq                                               1          7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.Avatar.value_counts()
# Out:
# Avatar
# SlateBlue               7
# Cyan                    7
# CadetBlue               7
# GreenYellow             7
# Teal                    7
#                        ..
# MediumPurple            1
# CornflowerBlue          1
# LightGoldenRodYellow    1
# PowderBlue              1
# LawnGreen               1
# Name: count, Length: 138, dtype: int64

# %%
df.Avatar.nunique()
# Out:
# 138

# %%
for col in df.columns:
    print(f"{col}:",df[col].nunique())
# Out:
# Email: 500
# Address: 500
# Avatar: 138
# Avg. Session Length: 500
# Time on App: 500
# Time on Website: 500
# Length of Membership: 500
# Yearly Amount Spent: 500

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# ### i. Univariate Analysis

# %% [markdown]
# #### a. Numerical Column

# %%
con_col = df.iloc[:, 3:]
con_col.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
for col in con_col.columns:
    plt.figure(figsize=(8,4))
    sns.histplot(x=col, data=df, kde = True)
    plt.tight_layout()
    plt.show()

# %%
# checking skewness and kurtosis
from scipy.stats import kurtosis, skew
for col in con_col:
    skewness = skew(df[col])
    kurt = kurtosis(df[col])
    print(f"Skewness of {col}: {skewness}")
    print(f"Kurtosis of {col}: {kurt}")
# Out:
# Skewness of Avg. Session Length: -0.03207820208079125
# Kurtosis of Avg. Session Length: -0.00023270464251412548
# Skewness of Time on App: -0.08885351110322988
# Kurtosis of Time on App: 0.1118578475296772
# Skewness of Time on Website: 0.012105424233404041
# Kurtosis of Time on Website: -0.10928282662789623
# Skewness of Length of Membership: -0.10628796203551294
# Kurtosis of Length of Membership: 0.3335533988857735
# Skewness of Yearly Amount Spent: 0.03468572646546662
# Kurtosis of Yearly Amount Spent: 0.4473727020891247

# %% [markdown]
# #### b. Categorical Column

# %%
cat_cols = df.iloc[:,:3]
cat_cols
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# Count top 20 categories
top_n = 20
for col in cat_cols:
    
    value_counts = df[col].value_counts()
    top_categories = value_counts[:top_n]
    others = value_counts[top_n:].sum()
    
    # Plotting
    plt.figure(figsize=(12, 6))
    sns.barplot(x=top_categories.values, y=top_categories.index, palette="viridis")
    plt.title(f"Top {top_n} Categories in '{col}'")
    plt.xlabel("Count")
    plt.ylabel("Category")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### ii. Bivariate Analysis

# %%
for col in con_col:    
    plt.figure(figsize=(8,4))
    sns.relplot(x=col, y=df['Yearly Amount Spent'], data = df)
    plt.tight_layout()
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(8,4))
    sns.relplot(x=col,y=df['Yearly Amount Spent'], data=df)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### iii. Multivariate Analysis

# %%
sns.pairplot(con_col)

# %% [markdown]
# ## 5. Data Preprocessing

# %% [markdown]
# ### i. Checking for null values/Outliers

# %%
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
for col in con_col:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=col, data=df)
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
for col in df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lb = q1 - iqr * 1.5
    ub = q3 + iqr * 1.5
    print(f"{col} lb is:", lb)
    print(f"{col} ub is:", ub)
    median = df[col].median()
    print(f"{col} Median is:", median)
    print("------------------------------------------------------")
# Out:
# Avg. Session Length lb is: 30.28657747536273
# Avg. Session Length ub is: 35.767229553109516
# Avg. Session Length Median is: 33.08200760262899
# ------------------------------------------------------
# Time on App lb is: 9.3396088251313
# Time on App ub is: 14.802394229583683
# Time on App Median is: 11.983231258825267
# ------------------------------------------------------
# Time on Website lb is: 34.29849491039147
# Time on Website ub is: 39.76719469493466
# Time on Website Median is: 37.069366582835826
# ------------------------------------------------------
# Length of Membership lb is: 1.136371357955959
# Length of Membership ub is: 5.920580296370714
# Length of Membership Median is: 3.5339750035877096
# ------------------------------------------------------

# %%
# df.loc[(df['Avg. Session Length'] < 30.29) | (df['Avg. Session Length'] > 35.77), 'Avg. Session Length'] = 33.08

# %%
# df.loc[(df['Time on App'] < 9.34) | (df['Time on App'] > 14.80), 'Time on App'] = 11.98

# %%
# df.loc[(df['Time on Website'] < 34.30) | (df['Time on Website'] > 39.77), 'Time on Website'] = 37.07

# %%
# df.loc[(df['Length of Membership'] < 1.14) | (df['Length of Membership'] > 5.92), 'Length of Membership'] = 3.53

# %%
# Important Note:
# I have replaced Outliers with the median but it drops the performance of the model so that i have commented it

# %%
for col in df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=col, data=df)
    plt.show()

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %% [markdown]
# ### ii. Scalling

# %%
# Important Note:
# We have done scalling but it drops the model performance so we are using original(without scaled) dataset

# %%
from sklearn.preprocessing import StandardScaler

features = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[features] = scaler.fit_transform(df[features])

# %%
df_scaled

# %%
# We Don't need to encode because there is not imp column in Object so we are removing it.
# df_scaled.drop(['Email', 'Address', 'Avatar'], axis=1, inplace = True)
df.drop(['Email', 'Address', 'Avatar'], axis=1, inplace = True)

# %%
df
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %% [markdown]
# ## 6. Feature Selection

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 7. Feature Extraction

# %%
from sklearn.decomposition import PCA

pca = PCA()
pc = pca.fit_transform(df)

# Cumulative explained variance
cum_var = np.cumsum(pca.explained_variance_ratio_)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cum_var)+1), cum_var * 100, marker='o', linestyle='-')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance (%)')
plt.title('Explained Variance by PCA')
plt.grid(True)
plt.show()

# %%
# We are not extracting as we need column to examine and give summary to the company
df
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %% [markdown]
# ## 8. Split the data

# %%
X = df.iloc[:,:4]
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y = df[['Yearly Amount Spent']]
y
# Out:
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print("X_train size:",X_train.shape)
print("X_test size:",X_test.shape)
print("y_train size:",y_train.shape)
print("y_test size:",y_test.shape)
# Out:
# X_train size: (350, 4)
# X_test size: (150, 4)
# y_train size: (350, 1)
# y_test size: (150, 1)

# %% [markdown]
# ## 9. Model Creation

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(X_test)

# %%
y_test = y_test.reset_index(drop=True)

# %%
y_test.head()
# Out:
#    Yearly Amount Spent
# 0           494.687156
# 1           501.122492
# 2           563.672873
# 3           469.310861
# 4           402.167122

# %%
y_predict
# Out:
# array([[498.81705536],
#        [519.53403729],
#        [562.94886718],
#        [478.90501346],
#        [423.8201042 ],
#        [508.9452329 ],
#        [478.79059717],
#        [460.08112597],
#        [519.38576043],
#        [439.12699354],
#        [487.54907742],
#        [525.96826109],
#        [577.12393843],
#        [553.53565548],
#        [685.14181281],
#        [473.40359409],
#        [314.71860742],
#        [458.39761038],
#        [452.38929377],
#        [461.05452656],
#        [456.35300072],
#        [332.21392109],
#        [504.18566874],
#        [401.88060608],
#        [766.19989355],
#        [425.98233166],
#        [513.22023323],
#        [476.80244451],
#        [306.817882  ],
#        [590.05645167],
#        [505.29246026],
#        [390.12626034],
#        [463.7152543 ],
#        [316.10191094],
#        [465.93448787],
#        [549.73327826],
#        [619.77113721],
#        [591.76573022],
#        [495.80310959],
#        [402.82346134],
# ...

# %% [markdown]
# ## 10. Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
y_predict = LR.predict(X_test)
print("R2 score:",r2_score(y_test, y_predict))
print("MAE:",mean_absolute_error(y_test, y_predict))
print("MSE:",mean_squared_error(y_test, y_predict))
# Out:
# R2 score: 0.9884637234896453
# MAE: 7.0991245940938645
# MSE: 80.90062369759981

# %%
df
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %% [markdown]
# ## 11. Suggestion to the Problems

# %%
from sklearn import metrics
coeff_df = pd.DataFrame(LR.coef_.T, index=X.columns, columns=['Coefficient'])
print(coeff_df)
# Out:
#                       Coefficient
# Avg. Session Length     25.827920
# Time on App             38.809001
# Time on Website          0.281743
# Length of Membership    61.304799

# %% [markdown]
# ### 1. What drives higher spending?
#
# According to the linear regression model, the following features drive higher spending:
#
# - **Length of Membership (61.30)** is the strongest driver. Customers who have been members for longer tend to spend more.
# - **Time on App (38.81)** is also a significant driver. Users who spend more time on the app tend to have higher spending.
# - **Avg. Session Length (25.83)** shows a moderate positive impact.
# - **Time on Website (0.28)** has very little impact on spending.
#
# **Conclusion**: Customers who have been members longer and actively use the app with longer session durations are more likely to spend more.
#
# ---
#
# ### 2. How usage patterns differ between app vs. website?
#
# The coefficient for **Time on App** is significantly higher than **Time on Website**:
#
# - Time on App: 38.81
# - Time on Website: 0.28
#
# **Conclusion**: Spending time on the app is much more strongly associated with higher yearly spending compared to the website. This suggests the app is more effective at converting user activity into purchases.
#
# ---
#
# ### 3. Which features correlate strongly with the Yearly Amount Spent?
#
# Based on the model coefficients:
#
# 1. Length of Membership → 61.30
# 2. Time on App → 38.81
# 3. Avg. Session Length → 25.83
# 4. Time on Website → 0.28
#
# **Conclusion**: The strongest correlation is with Length of Membership, followed by Time on App. Time on Website shows almost no correlation.
